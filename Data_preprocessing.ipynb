# %%
import numpy as np
import pandas as pd

# %%
data = {
    
    "Age": [25,30,35,40,45],
    "Premium": [18000,32000,42000,47000,55000]
}

df = pd.DataFrame(data)
print(df)
# Out:
#    Age  Premium
# 0   25    18000
# 1   30    32000
# 2   35    42000
# 3   40    47000
# 4   45    55000

# %%
x=df['Age']

# %%
x
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# 4    45
# Name: Age, dtype: int64

# %%
y=df['Premium']

# %%
y
# Out:
# 0    18000
# 1    32000
# 2    42000
# 3    47000
# 4    55000
# Name: Premium, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
# 4    45
# 2    35
# 0    25
# 3    40
# Name: Age, dtype: int64

# %%
x_test
# Out:
# 1    30
# Name: Age, dtype: int64

# %%
import seaborn as sns

# %%
sns.lmplot(x='Age',y='Premium',data=df)

# %%
from sklearn import linear_model

# %%
model=linear_model.LinearRegression()

# %%
model.fit(df[['Age']],df['Premium'])
# Out:
# LinearRegression()

# %%
model.predict([[33]])
# Out:
# C:\Users\shaya\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([35240.])

# %%
model.coef_
# Out:
# array([1780.])

# %%
model.intercept_
# Out:
# np.float64(-23500.0)
